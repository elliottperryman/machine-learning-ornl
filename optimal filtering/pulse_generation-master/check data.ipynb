# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = loadtxt("my1")

# %%
data
# Out:
# array([[-115., -112., -105., ...,  -30.,  -22.,  -26.],
#        [-133., -134., -136., ...,  -21.,  -20.,  -24.],
#        [-120., -121., -120., ...,  -52.,  -49.,  -52.],
#        ...,
#        [-128., -132., -141., ...,   80.,   86.,   99.],
#        [-106., -108., -114., ...,  -23.,  -20.,  -20.],
#        [-127., -119., -106., ...,   95.,   96.,   95.]])

# %%
plot(data[-6])
