# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.load('ff3.npy')

# %%
fig = plt.figure(figsize=(12,8))
#for i in range(6):
plt.plot(np.arange(100,1100,100),data)
plt.grid(b=True)
#plt.plot(np.arange(100,1100,100),data[:,i],label='threshold=95%')
plt.title("Accuracy with No Pile-up")
plt.legend(loc=4)
plt.ylabel('Accuracy')
plt.xlabel('Energy (ADC)')
plt.ylim((0,1.01));
plt.savefig('plots/ff3.png');
#plt.close()
# Out:
# No handles with labels found to put in legend.
