# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = append(zeros(1750),ones(1750))+random.normal(scale=1,size=3500) + 3*sin(0.006)

# %%
plot(data)

# %%
plot(sin(0.0006*arange(3500)))

# %%
plot(sin(0.002*arange(3500)))

# %%
0.002 - 0.0006
# Out:
# 0.0014000000000000002

# %%
0.0014000000000000002 + 0.002
# Out:
# 0.0034000000000000002
