# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = loadtxt("data/data.data")

# %%
data[-1]
# Out:
# array([-135., -142., -151., ...,   20.,   10.,    7.])

# %%
data[-2]
# Out:
# array([-142., -145., -139., ...,  -27.,  -28.,  -36.])

# %%
sum(data[-2]-data[-1])
# Out:
# -342956.0

# %%
plot(data[0])

# %%
plot(data[-10])

# %%
hist([max(x) for x in data], bins=100, histtype='step');

# %%
hist([max(x) for x in data[:int(len(data)/2)]], bins=100, histtype='step');

# %%
hist([max(x) for x in data[int(len(data)/2):]], bins=100, histtype='step');
